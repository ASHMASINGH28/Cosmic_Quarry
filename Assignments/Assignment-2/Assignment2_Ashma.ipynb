# %% [markdown]
# ## Section 1: Python Basics
# Learn about Python syntax, data types, and basic programming constructs.

# %%
print("Welcome to Python Basics!")

# %%
a = 10
b = 3.5
c = "Hello"
print(a, b, c)

# %%
my_list = [1, 2, 3, 4]
print("List:", my_list)

# %%
my_tuple = (1, 2, 3)
my_set = {1, 2, 2, 3}
print("Tuple:", my_tuple)
print("Set:", my_set)

# %%
my_dict = {"name": "Alice", "age": 25}
print("Dictionary:", my_dict)

# %%
for i in my_list:
    print("Element:", i)

# %%
x = 5
if x > 0:
    print("Positive")
elif x == 0:
    print("Zero")
else:
    print("Negative")

# %%
def greet(name):
    return f"Hello, {name}!"

print(greet("Student"))

# %% [markdown]
# ## Section 2: NumPy Basics
# Use NumPy for array operations, reshaping, and simulating image pixel data.

# %%
import numpy as np

# %%
arr = np.array([1, 2, 3])
print("Numpy Array:", arr)

# %%
print("Mean:", np.mean(arr))
print("Sum:", np.sum(arr))

# %%
mat = np.array([[1, 2], [3, 4]])
print("Matrix:", mat)

# %%
rand_arr = np.random.rand(3, 3)
print("Random Array:\n", rand_arr)

# %%
reshaped = np.arange(12).reshape(3, 4)
print("Reshaped Array:\n", reshaped)

# %%
broadcasted = arr + 10
print("Broadcasted Array:", broadcasted)
indexing = reshaped[1:, 1:]
print("Sliced Array:\n", indexing)

# %%
img = np.random.randint(0, 256, (5, 5), dtype=np.uint8)
print("Simulated Grayscale Image Array:\n", img)

# %% [markdown]
# ## Section 3: Pandas Basics
# Manipulate tabular data with DataFrames: filtering, grouping, and merging.

# %%
import pandas as pd

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'Marks': [85, 90, 95]
}
df = pd.DataFrame(data)
print("DataFrame:\n", df)
# Out:
# DataFrame:
#        Name  Age  Marks
# 0    Alice   25     85
# 1      Bob   30     90
# 2  Charlie   35     95

# %%
print("Describe:\n", df.describe())
print("Select Name column:\n", df['Name'])

# %%
young = df[df['Age'] < 30]
print("Age < 30:\n", young)

# %%
df['Passed'] = df['Marks'] > 80
print("With Passed Column:\n", df)

# %%
grouped = df.groupby('Passed')['Marks'].mean()
print("Group By Passed:\n", grouped)

# %%
df_missing = df.copy()
df_missing.loc[1, 'Marks'] = None
print("With Missing Data:\n", df_missing)
print("Filled Missing Marks:\n", df_missing['Marks'].fillna(df_missing['Marks'].mean()))
# Out:
# With Missing Data:
#        Name  Age  Marks
# 0    Alice   25   85.0
# 1      Bob   30    NaN
# 2  Charlie   35   95.0
# Filled Missing Marks:
#  0    85.0
# 1    90.0
# 2    95.0
# Name: Marks, dtype: float64

# %%
df_extra = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Subject': ['Math', 'Science', 'History']
})
merged = pd.merge(df, df_extra, on='Name')
print("Merged DataFrame:\n", merged)

# %% [markdown]
# ## Section 4: Matplotlib Basics
# Create visualizations like line charts, bar plots, scatter plots, and pie charts.

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1, 2, 3], [5, 7, 4])
plt.title("Line Plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.grid(True)
plt.show()

# %%
plt.bar(df['Name'], df['Marks'], color='orange')
plt.title("Marks of Students")
plt.xlabel("Students")
plt.ylabel("Marks")
plt.show()

# %%
plt.hist(df['Marks'], bins=5)
plt.title("Histogram of Marks")
plt.xlabel("Marks")
plt.ylabel("Frequency")
plt.show()

# %%
plt.scatter(df['Age'], df['Marks'])
plt.title("Age vs Marks")
plt.xlabel("Age")
plt.ylabel("Marks")
plt.show()

# %%
plt.pie(df['Marks'], labels=df['Name'], autopct='%1.1f%%')
plt.title("Marks Distribution")
plt.show()

# %% [markdown]
# ## Section 5: Exercises
# Practice problems to reinforce concepts in NumPy, Pandas, and Matplotlib.

# %%
# 1. Create a NumPy array of 10 numbers and calculate mean and std deviation
# 2. Load a CSV file using Pandas (or create one manually)
# 3. Plot a histogram of a numerical column using Matplotlib
# 4. Filter a DataFrame for rows with marks > 90
# 5. Use a scatter plot to visualize relationship between Age and Marks
# 6. Try reading an Excel file using pd.read_excel if you have one
# 7. Merge two DataFrames on a common column
# 8. Handle missing values in a DataFrame
# 9. Simulate a grayscale image and display its pixel values using NumPy

# %% [markdown]
# creating numpy array of 10 numbers and calculating mean and std deviation

# %%
import numpy as np
a=[1,2,4,8,9,5,10,17,19,20]
np.array(a)
# Out:
# array([ 1,  2,  4,  8,  9,  5, 10, 17, 19, 20])

# %%
mean=np.mean(a)
print(mean)
# Out:
# 9.5

# %%
stddev=np.std(a)
print(stddev)
# Out:
# 6.621933252457322

# %% [markdown]
# loading csv file using pandas

# %%
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\DELL\Downloads\Iris.csv")

# %%
from matplotlib import pyplot as plt

# %%
data['SepalLengthCm'].plot(kind='hist',bins=20,edgecolor='black')
plt.title("Sepal length")
plt.xlabel("Length")
plt.ylabel("Frequency")
plt.show()

# %%
data['PetalLengthCm'].plot(kind='hist',bins=20,edgecolor='black')
plt.title("Petal length")
plt.xlabel("Length")
plt.ylabel("Frequency")
plt.show()

# %%
data['SepalWidthCm'].plot(kind='hist',bins=20,edgecolor='black')
plt.title("Sepal width")
plt.xlabel("Width")
plt.ylabel("Frequency")
plt.show()

# %%
data['PetalWidthCm'].plot(kind='hist',bins=20,edgecolor='black')
plt.title("Petal width")
plt.xlabel("Width")
plt.ylabel("Frequency")
plt.show()

# %%
plt.scatter(data["SepalLengthCm"],data["PetalLengthCm"])
plt.title("Sepal length vs Petal length")
plt.xlabel("Petal Length")
plt.ylabel("Sepal length")
plt.show()

# %%
filtered_data=data[data["PetalLengthCm"]>6]
print(filtered_data)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 105  106            7.6           3.0            6.6           2.1
# 107  108            7.3           2.9            6.3           1.8
# 109  110            7.2           3.6            6.1           2.5
# 117  118            7.7           3.8            6.7           2.2
# 118  119            7.7           2.6            6.9           2.3
# 122  123            7.7           2.8            6.7           2.0
# 130  131            7.4           2.8            6.1           1.9
# 131  132            7.9           3.8            6.4           2.0
# 135  136            7.7           3.0            6.1           2.3
#
#             Species
# 105  Iris-virginica
# 107  Iris-virginica
# 109  Iris-virginica
# 117  Iris-virginica
# 118  Iris-virginica
# 122  Iris-virginica
# 130  Iris-virginica
# 131  Iris-virginica
# 135  Iris-virginica

# %%
data1={
    "Name": ["Rohit","Krishna","Nikhil","Shreya"],
    "Age": [17,18,18,16],
    "Goals": [5,9,4,6]
}
data2={
    "Name": ["Rohit","Krishna","Nikhil","Shreya"],
    "Team": ["Manchester City","Barcelona","Inter Milan","Arsenal"],
    "Contract": [3,5,6,5]
}
df1=pd.DataFrame(data1)
df2=pd.DataFrame(data2)
new= pd.merge(df1,df2,on="Name")
print("Meged Dtaframe\n",new)
# Out:
# Meged Dtaframe
#        Name  Age  Goals             Team  Contract
# 0    Rohit   17      5  Manchester City         3
# 1  Krishna   18      9        Barcelona         5
# 2   Nikhil   18      4      Inter Milan         6
# 3   Shreya   16      6          Arsenal         5

# %%
df_new=df1.copy()
df_new.loc[1,"Goals"] = None
print(df1["Goals"].fillna(df1["Goals"].mean()))
# Out:
# 0    5
# 1    9
# 2    4
# 3    6
# Name: Goals, dtype: int64

# %%
import cv2

# %%
img=cv2.imread(r"C:\Users\DELL\Pictures\Saved Pictures\cp.PNG",cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(img,cmap="gray")
plt.axis("off")
plt.show()
